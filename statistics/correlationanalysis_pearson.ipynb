# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy as sp

x = [90, 64, 94, 57, 82, 92, 84, 72, 52, 86, 73, 82, 78, 68, 54, 92, 65, 76, 83, 95]
y = [86, 65, 89, 62, 74, 64, 98, 85, 62, 84, 84, 83, 59, 64, 55, 95, 70, 72, 88, 93]

plt.scatter(x, y, color='b', s=20)
plt.xlabel('math_grade')
plt.ylabel('science_grade')
plt.show()

print(np.corrcoef(x,y))
print(sp.stats.pearsonr(x,y))
# Out:
# [[1.         0.71270975]
#  [0.71270975 1.        ]]
# PearsonRResult(statistic=np.float64(0.7127097462660571), pvalue=np.float64(0.00042100297010646))
